# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



import warnings

warnings.filterwarnings('ignore')

# %%
dataset_path='https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/life.csv'

df = pd.read_csv(dataset_path)
df
# Out:
#                                 Country  Year  Adult Mortality  infant deaths  \
# 0                           Afghanistan  2015            263.0             62
# 1                               Albania  2015             74.0              0
# 2                               Algeria  2015             19.0             21
# 3                                Angola  2015            335.0             66
# 4                   Antigua and Barbuda  2015             13.0              0
# ..                                  ...   ...              ...            ...
# 178  Venezuela (Bolivarian Republic of)  2015            157.0              9
# 179                            Viet Nam  2015            127.0             28
# 180                               Yemen  2015            224.0             37
# 181                              Zambia  2015             33.0             27
# 182                            Zimbabwe  2015            336.0             22
#
# ...

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Adult Mortality                    float64
# infant deaths                        int64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# Life_exp                           float64
# dtype: object

# %%
df['percentage expenditure']
# Out:
# 0       71.279624
# 1      364.975229
# 2        0.000000
# 3        0.000000
# 4        0.000000
#           ...
# 178      0.000000
# 179      0.000000
# 180      0.000000
# 181      0.000000
# 182      0.000000
# Name: percentage expenditure, Length: 183, dtype: float64

# %%
df = df.drop(columns='percentage expenditure')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df = df.drop(columns='percentage expenditure')
#
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df = df.drop(columns='Year')

# %%
df = df.drop(columns='Country')

# %%
df.isna().sum()
# Out:
# Adult Mortality                    0
# infant deaths                      0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Diphtheria                         0
#  HIV/AIDS                          0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# Life_exp                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Adult Mortality                  183 non-null    float64
#  1   infant deaths                    183 non-null    int64
#  2   Hepatitis B                      183 non-null    float64
#  3   Measles                          183 non-null    int64
#  4    BMI                             183 non-null    float64
#  5   under-five deaths                183 non-null    int64
#  6   Polio                            183 non-null    float64
#  7   Diphtheria                       183 non-null    float64
#  8    HIV/AIDS                        183 non-null    float64
#  9    thinness  1-19 years            183 non-null    float64
#  10   thinness 5-9 years              183 non-null    float64
#  11  Income composition of resources  183 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Adult Mortality  infant deaths  Hepatitis B      Measles         BMI   \
# count       183.000000     183.000000   183.000000    183.000000  183.000000
# mean        152.863388      23.803279    82.425287   1502.901639   42.754144
# std          97.561184      83.683762    23.407349   7842.394928   20.571730
# min           1.000000       0.000000     6.000000      0.000000    2.500000
# 25%          74.000000       0.000000    81.000000      0.000000   24.300000
# 50%         138.000000       2.000000    92.000000     17.000000   48.600000
# 75%         213.000000      17.000000    97.000000    202.000000   61.350000
# max         484.000000     910.000000    99.000000  90387.000000   77.600000
#
#        under-five deaths        Polio  Diphtheria     HIV/AIDS  \
# count          183.000000  183.000000   183.000000  183.000000
# mean            31.612022   83.207650    84.633880    0.660656
# std            107.779778   24.245778    22.162793    1.344702
# ...

# %%
df.hist(figsize=(20,10));

# %%
sns.heatmap(df.corr(), annot=False)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                                  Adult Mortality  infant deaths  Hepatitis B  \
# Adult Mortality                         1.000000       0.188205    -0.227031
# infant deaths                           0.188205       1.000000    -0.086727
# Hepatitis B                            -0.227031      -0.086727     1.000000
# Measles                                 0.051196       0.800859     0.015627
#  BMI                                   -0.365879      -0.223459     0.171990
# under-five deaths                       0.212004       0.994196    -0.104492
# Polio                                  -0.372392      -0.129729     0.590183
# Diphtheria                             -0.322688      -0.117989     0.909236
#  HIV/AIDS                               0.621012       0.095837    -0.382053
#  thinness  1-19 years                   0.294761       0.530298    -0.055650
#  thinness 5-9 years                     0.299392       0.530302    -0.096178
# ...

# %%
X = df.drop(columns = 'Life_exp')
y = df['Life_exp']

# %%
X
# Out:
#      Adult Mortality  infant deaths  Hepatitis B  Measles    BMI   \
# 0              263.0             62         65.0      1154   19.1
# 1               74.0              0         99.0         0   58.0
# 2               19.0             21         95.0        63   59.5
# 3              335.0             66         64.0       118   23.3
# 4               13.0              0         99.0         0   47.7
# ..               ...            ...          ...       ...    ...
# 178            157.0              9         87.0         0   62.1
# 179            127.0             28         97.0       256   17.5
# 180            224.0             37         69.0       468   41.3
# 181             33.0             27          9.0         9   23.4
# 182            336.0             22         87.0         0   31.8
#
#      under-five deaths   Polio  Diphtheria    HIV/AIDS   thinness  1-19 years  \
# 0                    83    6.0         65.0        0.1                   17.2
# ...

# %%
y
# Out:
# 0      65.0
# 1      77.8
# 2      75.6
# 3      52.4
# 4      76.4
#        ...
# 178    74.1
# 179    76.0
# 180    65.7
# 181    61.8
# 182    67.0
# Name: Life_exp, Length: 183, dtype: float64

# %%
X.ndim
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                test_size = 0.2,
                                                random_state=667
                                                )

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-2.98104327e-02,  8.69153644e-02,  2.75531888e-02, -4.25947075e-05,
#         1.38515742e-02, -6.39754943e-02,  1.38793079e-02,  1.09043445e-02,
#        -4.31597801e-01, -2.86336016e-01,  3.41159404e-03,  2.41430940e+01,
#        -2.57118503e-03])

# %%
model.intercept_
# Out:
# 55.99843051871995

# %%
y_pred = model.predict(X_test)

# %%
length = y_pred.shape[0] 
x = np.linspace(0,length,length)


plt.figure(figsize=(30,15))
plt.plot(x, y_test, label='life exp reale')
plt.plot(x, y_pred, label='life exp predetta')
plt.legend(loc=2);

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

r2score = r2_score(y_test, y_pred)
r2score
# Out:
# 0.8841914157967063

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.9770870202711612

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 7.092041562405332

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
rmse
# Out:
# 2.663088725973157

# %%
import joblib
joblib.dump(model, 'lifeexp_regression.pkl')
# Out:
# ['lifeexp_regression.pkl']
